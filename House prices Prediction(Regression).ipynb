# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
house=pd.read_csv("C:/Users/Youniz/Documents/house_train.csv")
house=pd.read_csv("C:/Users/Youniz/Documents/house_train.csv")
house_test=pd.read_csv("C:/Users/Youniz/Documents/house_test.csv")
house_test_sample=pd.read_csv("C:/Users/Youniz/Documents/house_test.csv")

# %%
house.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
house.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageCond         81
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageQual         81
# BsmtExposure       38
# BsmtFinType2       38
# BsmtFinType1       37
# BsmtCond           37
# BsmtQual           37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# Utilities           0
# YearRemodAdd        0
# MSSubClass          0
# Foundation          0
# ExterCond           0
# ExterQual           0
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
# RoofStyle           0
# YearBuilt           0
#                  ...
# GarageArea          0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# 3SsnPorch           0
# BsmtUnfSF           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# ...

# %%
house.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
# %matplotlib inline

# %%
house.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
house.get_dtype_counts()
# Out:
# float64     3
# int64      35
# object     43
# dtype: int64

# %%
house.corr()["SalePrice"].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
correlations=house.corr()
attrs = correlations.iloc[:,:-1] # all except target
print(attrs)
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
sns.distplot(house.SalePrice,kde=True,color="b")
fig = plt.figure()
res = stats.probplot(house['SalePrice'], plot=plt)

# %%
#'SalePrice' is not normal. It shows 'peakedness', positive skewness and does not follow the diagonal line.We will apply log transformation to solve skew problem.
house["SalePrice"]=np.log1p(house["SalePrice"])
sns.distplot(house["SalePrice"],fit=norm);
plt.figure()
res=stats.probplot(house["SalePrice"],plot=plt)

# %%
corr = house.corr()
plt.figure(figsize=(12, 12))
sns.heatmap(corr, vmax=1, square=True)

# %%
corr=house.corr()["SalePrice"]
#corr[np.argsort(corr, axis=0)[::-1]]
corr[corr>0.3].sort_values(ascending=False)
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# GarageYrBlt     0.486362
# MasVnrArea      0.477493
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# LotFrontage     0.351799
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# Name: SalePrice, dtype: float64

# %%
sns.regplot(x="GrLivArea",y="SalePrice",data=house)

# %%
# we see there are outiers in GrLivArea which was sold for very less amount so we can replace with 99.5 percentile.

upperlimit = np.percentile(house.GrLivArea.values, 99.5)

house['GrLivArea'].ix[house['GrLivArea']>upperlimit] = upperlimit
# Out:
# C:\Users\Youniz\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\Youniz\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sns.regplot(x="GrLivArea",y="SalePrice",data=house)

# %%
# now we have removed those outliers as You can from the above scatter plot.
#we will plot the strongest correlated variable OverallQual

sns.regplot(x="OverallQual",y="SalePrice",data=house)

# %%
# as the Overallqual increases the saleprice also increases.
sns.regplot(x="GarageCars",y="SalePrice",data=house)

# %%
sns.regplot(x="GarageArea",y="SalePrice",data=house)

# %%
#Garage Area has some outliers at the right corner we will change to 99.5 percentile

upperlimit=np.percentile(house.GarageArea.values,99.5)
house["GarageArea"].ix[house["GarageArea"]>upperlimit]=upperlimit
# Out:
# C:\Users\Youniz\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sns.regplot(x="TotalBsmtSF",y="SalePrice",data=house)

# %%
#totalBsmtSF has some outliers at the right corner we will change to 99.5 percentile

upperlimit=np.percentile(house.TotalBsmtSF.values,99.5)
house["TotalBsmtSF"].ix[house["TotalBsmtSF"]>upperlimit]=upperlimit
# Out:
# C:\Users\Youniz\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sns.swarmplot("FullBath","SalePrice",data=house)

# %%
sns.regplot(x="1stFlrSF",y="SalePrice",data=house)

# %%
upperlimit1=np.percentile(house["1stFlrSF"].values,99.5)
house["1stFlrSF"].ix[house["1stFlrSF"]>upperlimit1]=upperlimit1
# Out:
# C:\Users\Youniz\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\Youniz\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sns.regplot(x="1stFlrSF",y="SalePrice",data=house)

# %%
sns.boxplot("BedroomAbvGr","SalePrice",data=house)

# %%
sns.boxplot(x="SaleType",y="SalePrice",data=house)

# %%
g=sns.FacetGrid(house,col="YrSold",col_wrap = 3)
g.map(sns.boxplot, 'MoSold', 'SalePrice', palette='Set2',order=range(1,13))\
.set(ylim = (0, 500000))
plt.tight_layout()

# %%
plt.figure(figsize = (12, 6))
plt.scatter(house.YearRemodAdd.values,house.SalePrice)

# %%
house['ConstructionAge'] = house['YrSold'] - house['YearBuilt']
plt.scatter(house['ConstructionAge'], house['SalePrice'])

# %%
plt.figure(figsize = (12, 6))
plt.scatter(house.YearBuilt.values,house.SalePrice)

# %%
#Older Built houses have less price when compared to New built house or new remodeled house.

plt.figure(figsize=(6,6))
sns.barplot(x=house.MasVnrType,y=house.SalePrice,data=house)

# %%
plt.figure(figsize=(6,6))
sns.barplot(x=house.Fireplaces,y=house.SalePrice,data=house)

# %%
#For MasVnrType(Masonry veneertype) Stone type has high price.
#Now we will  filter the categorical variables
house.select_dtypes(include=["object"]).columns.values
# Out:
# array(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'], dtype=object)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=house.Neighborhood,y=house.SalePrice,data=house)
xt=plt.xticks(rotation=45)

# %%
#Noridge,NridgHt and StoneBr are high price neighbourhood

# %%
#House Style and Heating Facilities

fig,ax=plt.subplots(2,1,figsize=(10,6))
sns.boxplot(house.HouseStyle,house.SalePrice,data=house,ax=ax[0])
sns.boxplot(house.Heating,house.SalePrice,data=house,ax=ax[1])
plt.tight_layout()

# %%
#Gas A and Gas W has high no of saleprice compared to others

#Kitchen

plt.figure(figsize=(6,4))
sns.barplot(house.KitchenQual,house.SalePrice,data=house)

# %%
     
fig, ax = plt.subplots(2, 1, figsize = (10, 8))
sns.boxplot(x = 'Condition1', y = 'SalePrice', data =house, ax = ax[0])
sns.boxplot(x = 'Exterior1st', y = 'SalePrice', data =house, ax = ax[1])
x = plt.xticks(rotation = 45)
plt.show()

# %%
     

fig, ax = plt.subplots(2, 2, figsize = (10, 8))
sns.boxplot('BsmtCond', 'SalePrice', data = house, ax = ax[0, 0])
sns.boxplot('BsmtQual', 'SalePrice', data = house, ax = ax[0, 1])
sns.boxplot('BsmtExposure', 'SalePrice', data = house, ax = ax[1, 0])
sns.boxplot('BsmtFinType1', 'SalePrice', data = house, ax = ax[1, 1])

# %%
#excellent Basement quality has an impact on Saleprice.
plt.figure(figsize=(10,6))
sns.swarmplot(x="Electrical",y="SalePrice",data=house)

# %%
#electrical type -SBrkr has been used majorly for houses

sns.violinplot('Functional', 'SalePrice', data = house)

# %%
sns.factorplot(x='FireplaceQu',y= 'SalePrice', data = house )

# %%
pd.crosstab(house.HeatingQC, house.CentralAir)
# Out:
# CentralAir   N    Y
# HeatingQC
# Ex           8  733
# Fa          24   25
# Gd          13  228
# Po           1    0
# TA          49  379

# %%
sns.factorplot('HeatingQC', 'SalePrice', hue = 'CentralAir' , data=house)

# %%
#Now we have to  handle Missing data, Lets first see how much data is missing out
total=house.isnull().sum().sort_values(ascending=False)
percent=(house.isnull().sum()*100/house.isnull().count()).sort_values(ascending=False)
missing_data=pd.concat([total,percent],axis=1,keys=["Total","Percent"])
missing_data.head(25)
# Out:
#               Total    Percent
# PoolQC         1453  99.520548
# MiscFeature    1406  96.301370
# Alley          1369  93.767123
# Fence          1179  80.753425
# FireplaceQu     690  47.260274
# LotFrontage     259  17.739726
# GarageQual       81   5.547945
# GarageCond       81   5.547945
# GarageFinish     81   5.547945
# GarageType       81   5.547945
# GarageYrBlt      81   5.547945
# BsmtExposure     38   2.602740
# BsmtFinType2     38   2.602740
# BsmtQual         37   2.534247
# BsmtCond         37   2.534247
# BsmtFinType1     37   2.534247
# MasVnrArea        8   0.547945
# MasVnrType        8   0.547945
# Electrical        1   0.068493
# RoofStyle         0   0.000000
# RoofMatl          0   0.000000
# ExterQual         0   0.000000
# Exterior1st       0   0.000000
# Exterior2nd       0   0.000000
# YearBuilt         0   0.000000

# %%
#We can  remove features which have more than 80%  missing data and also we can remove the ID feature.it does not help in predicting 
# same thing we can do for the Test data set.
house.drop("PoolQC",axis=1,inplace=True)

# %%
house.shape
# Out:
# (1460, 81)

# %%
house.head(5)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope       ...       3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl       ...               0           0
# 1    AllPub       FR2       Gtl       ...               0           0
# 2    AllPub    Inside       Gtl       ...               0           0
# 3    AllPub    Corner       Gtl       ...               0           0
# 4    AllPub       FR2       Gtl       ...               0           0
#
#   PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice  \
# ...

# %%
cols=["MiscFeature","Alley","Fence","Id"]
for i in cols:
    house.drop(i,axis=1,inplace=True)

# %%
house_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
house_test.shape
# Out:
# (1459, 80)

# %%
total1=house_test.isnull().sum().sort_values(ascending=False)
percent1=(house_test.isnull().sum()*100/house_test.isnull().count()).sort_values(ascending=False)
missing_data1=pd.concat([total1,percent1],axis=1)

# %%
missing_data1.head(35)
# Out:
#                    0          1
# FireplaceQu      730  50.034270
# LotFrontage      227  15.558602
# GarageYrBlt       78   5.346127
# GarageFinish      78   5.346127
# GarageCond        78   5.346127
# GarageQual        78   5.346127
# GarageType        76   5.209047
# BsmtCond          45   3.084304
# BsmtQual          44   3.015764
# BsmtExposure      44   3.015764
# BsmtFinType2      42   2.878684
# BsmtFinType1      42   2.878684
# MasVnrType        16   1.096642
# MasVnrArea        15   1.028101
# MSZoning           4   0.274160
# Functional         2   0.137080
# BsmtHalfBath       2   0.137080
# Utilities          2   0.137080
# BsmtFullBath       2   0.137080
# Exterior2nd        1   0.068540
# Exterior1st        1   0.068540
# TotalBsmtSF        1   0.068540
# KitchenQual        1   0.068540
# GarageCars         1   0.068540
# BsmtUnfSF          1   0.068540
# GarageArea         1   0.068540
# BsmtFinSF2         1   0.068540
# BsmtFinSF1         1   0.068540
# ...

# %%
cols1=["PoolQC","MiscFeature","Alley","Fence","Id"]
for i in cols1:
    house_test.drop(i,axis=1,inplace=True)

# %%
house.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
house_test.head(5)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          20       RH         80.0    11622   Pave      Reg         Lvl
# 1          20       RL         81.0    14267   Pave      IR1         Lvl
# 2          60       RL         74.0    13830   Pave      IR1         Lvl
# 3          60       RL         78.0     9978   Pave      IR1         Lvl
# 4         120       RL         43.0     5005   Pave      IR1         HLS
#
#   Utilities LotConfig LandSlope       ...       EnclosedPorch 3SsnPorch  \
# 0    AllPub    Inside       Gtl       ...                   0         0
# 1    AllPub    Corner       Gtl       ...                   0         0
# 2    AllPub    Inside       Gtl       ...                   0         0
# 3    AllPub    Inside       Gtl       ...                   0         0
# 4    AllPub    Inside       Gtl       ...                   0         0
#
#   ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# ...

# %%
house_test['ConstructionAge'] = house_test['YrSold'] - house_test['YearBuilt']

# %%
house["FireplaceQu"]=house["FireplaceQu"].fillna("None")

house_test["FireplaceQu"]=house_test["FireplaceQu"].fillna("None")

# %%
house.LotFrontage.hist()

# %%
house.shape[0]
# Out:
# 1460

# %%
house_test.shape[0]
# Out:
# 1459

# %%
ntrain=house.shape[0]
ntest=house_test.shape[0]
all_data = pd.concat((house,house_test)).reset_index(drop=True)

# %%
totalall=all_data.isnull().sum().sort_values(ascending=False)
total_percent=(all_data.isnull().sum()*100/all_data.isnull().count()).sort_values(ascending=False)

total_missing=pd.concat([totalall,total_percent],axis=1)

# %%
all_data["LotFrontage"]=all_data.groupby("Neighborhood")["LotFrontage"].transform(lambda x:x.fillna(x.median()))

# %%
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):

    all_data[col] = all_data[col].fillna('None')

# %%
for col in ("GarageArea","GarageCars","GarageYrBlt"):
     all_data[col]=all_data[col].fillna(0)

# %%
for col in ("BsmtHalfBath","BsmtFullBath","BsmtUnfSF","BsmtFinSF2","BsmtFinSF1","TotalBsmtSF"):
     all_data[col]=all_data[col].fillna(0)

# %%
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    all_data[col] = all_data[col].fillna('None')

# %%
all_data["MasVnrType"] = all_data["MasVnrType"].fillna("None")
all_data["MasVnrArea"] = all_data["MasVnrArea"].fillna(0)

# %%
all_data["MSZoning"]= all_data["MSZoning"].fillna(all_data["MSZoning"].mode()[0])
all_data["ConstructionAge"]=all_data["ConstructionAge"].fillna(0)

# %%
all_data["Functional"]= all_data["Functional"].fillna(all_data["Functional"].mode()[0])

# %%
all_data=all_data.drop(["Utilities"],axis=1)#same value in entire column

# %%
all_data['Electrical'] = all_data['Electrical'].fillna(all_data['Electrical'].mode()[0])
all_data['KitchenQual'] = all_data['KitchenQual'].fillna(all_data['KitchenQual'].mode()[0])
all_data['Exterior1st'] = all_data['Exterior1st'].fillna(all_data['Exterior1st'].mode()[0])
all_data['Exterior2nd'] = all_data['Exterior2nd'].fillna(all_data['Exterior2nd'].mode()[0])
all_data['SaleType'] = all_data['SaleType'].fillna(all_data['SaleType'].mode()[0])

# %%
categorical = all_data.select_dtypes(['object'])
#we are adding one more important feature
all_data['TotalSF'] = all_data['TotalBsmtSF'] + all_data['1stFlrSF'] + all_data['2ndFlrSF']

# %%
categorical.columns
# Out:
# Index(['BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'BsmtQual', 'CentralAir', 'Condition1', 'Condition2', 'Electrical',
#        'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd', 'FireplaceQu',
#        'Foundation', 'Functional', 'GarageCond', 'GarageFinish', 'GarageQual',
#        'GarageType', 'Heating', 'HeatingQC', 'HouseStyle', 'KitchenQual',
#        'LandContour', 'LandSlope', 'LotConfig', 'LotShape', 'MSZoning',
#        'MasVnrType', 'Neighborhood', 'PavedDrive', 'RoofMatl', 'RoofStyle',
#        'SaleCondition', 'SaleType', 'Street'],
#       dtype='object')

# %%
numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index

from scipy import stats
from scipy.stats import norm, skew

# %%
skewed_feats = all_data[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)

# %%
skewed_feats.head(15)
# Out:
# PoolArea         15.119426
# 3SsnPorch         8.924822
# LowQualFinSF      8.744143
# MiscVal           5.597060
# BsmtHalfBath      3.788243
# KitchenAbvGr      3.698825
# ScreenPorch       2.978396
# BsmtFinSF2        2.564481
# EnclosedPorch     2.025461
# MasVnrArea        0.636361
# HalfBath          0.590565
# BsmtFullBath      0.441864
# MSSubClass        0.380477
# SalePrice         0.368049
# 2ndFlrSF          0.327362
# dtype: float64

# %%
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness = skewness[abs(skewness) > 0.75]
from scipy.special import boxcox1p
skewed_features = skewness.index
lam = 0.15
for feat in skewed_features:
    #all_data[feat] += 1
    all_data[feat] = boxcox1p(all_data[feat], lam)

# %%
all_data.drop(["SalePrice"],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
cols = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2'
        , 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'CentralAir')

for c in cols:
    lbl = LabelEncoder() 
    lbl.fit(list(all_data[c].values)) 
    all_data[c] = lbl.transform(list(all_data[c].values))
print('Shape all_data: {}'.format(all_data.shape))
# Out:
# Shape all_data: (2919, 76)

# %%
train = all_data[:ntrain]
test = all_data[ntrain:]

# %%
test.tail(10)
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtCond  BsmtExposure  \
# 2909  2.995373  0.000000        0.0      0.571575         4             0
# 2910  2.949361  2.949361        0.0      1.000916         4             3
# 2911  3.238962  0.000000        0.0      1.000916         4             0
# 2912  2.949361  2.949361        0.0      1.000916         4             3
# 2913  2.949361  2.949361        0.0      1.000916         4             3
# 2914  2.949361  2.949361        0.0      1.000916         4             3
# 2915  2.949361  2.949361        0.0      1.000916         4             3
# 2916  3.205957  0.000000        0.0      1.121833         4             3
# 2917  3.132730  0.000000        0.0      1.000916         4             0
# 2918  3.141085  3.143610        0.0      1.000916         4             0
#
#       BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2     ...       \
# 2909    2.934855    0.000000             2             6     ...
# ...

# %%
all_data=pd.get_dummies(all_data)
print(all_data.shape)
# Out:
# (2919, 220)

# %%
train=all_data[:ntrain]
test=all_data[ntrain:]
y_train = house.SalePrice.values

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb

# %%
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
    rmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))

# %%
score = rmsle_cv(lasso)
print("\nLasso score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Lasso score: 0.1248 (0.0143)

# %%
lasso.fit(train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('robustscaler', RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True)), ('lasso', Lasso(alpha=0.0005, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False))])

# %%
final = pd.DataFrame()
test_id=house_test_sample["Id"]
final["Id"]=test_id

final["SalePrice"]=np.expm1(lasso.predict(test))
final.to_csv('submission2.csv', index=False) # Create Submission File

# %%
np.expm1(lasso.predict(test))
# Out:
# array([ 116119.40909885,  154050.36132841,  181633.47003577, ...,
#         170191.7493943 ,  119483.41138907,  224751.99202115])

# %%
from sklearn.decomposition import PCA
pca = PCA(whiten=True)
pca.fit(all_data)
variance = pd.DataFrame(pca.explained_variance_ratio_)
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([ 0.46177248,  0.55970167,  0.63317951,  0.66388408,  0.69166427,
#         0.71647008,  0.73926451,  0.75905993,  0.77760089,  0.79497675,
#         0.81026717,  0.82329749,  0.83484924,  0.8454268 ,  0.85553959,
#         0.86435239,  0.87198129,  0.87909459,  0.88566313,  0.89166365,
#         0.89749064,  0.90266869,  0.90766887,  0.91203741,  0.91614642,
#         0.92011971,  0.92389597,  0.92754141,  0.93088798,  0.93405705,
#         0.93715113,  0.9400496 ,  0.94263841,  0.94503697,  0.9473449 ,
#         0.94955744,  0.95160197,  0.95349775,  0.95527322,  0.95698862,
#         0.95861271,  0.96016862,  0.96169884,  0.96306274,  0.96441917,
#         0.96566429,  0.96686528,  0.96801788,  0.96913711,  0.97021392,
#         0.97126237,  0.97228589,  0.97324916,  0.97413308,  0.97496437,
#         0.97577788,  0.9765393 ,  0.97728912,  0.97799121,  0.97868279,
#         0.97936303,  0.98003568,  0.9806652 ,  0.9812802 ,  0.98187573,
# ...

# %%
pca = PCA(n_components=153,whiten=True)
pca = pca.fit(all_data)
dataPCA = pca.transform(all_data)
trainPCA = dataPCA[:1460]
testPCA = dataPCA[1460:]

# %%
n_folds = 5

def rmsle_cv1(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(trainPCA)
    rmse= np.sqrt(-cross_val_score(model, trainPCA, y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))

score = rmsle_cv1(lasso)
print("\nLasso score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Lasso score: 0.1331 (0.0115)

# %%
trainPCA
# Out:
# array([[ -1.07515348e+00,  -6.79698402e-01,   9.17004404e-03, ...,
#           2.07890952e-01,   1.13787164e-01,  -4.35105971e-01],
#        [  6.44046264e-01,  -1.11496055e+00,  -3.44797616e-01, ...,
#          -3.58092701e-01,  -1.98239495e-01,  -1.29883975e-01],
#        [ -1.16484701e+00,  -9.02308928e-01,   1.14480650e-01, ...,
#           3.99230014e-01,  -1.68015553e-01,   3.01073036e-02],
#        ...,
#        [ -1.45651846e+00,  -1.29984742e-01,  -6.79413407e-01, ...,
#           4.70396537e+00,   1.69490220e+00,  -9.64754849e-01],
#        [  8.63515078e-01,  -1.24674408e-01,  -8.94828443e-01, ...,
#           1.81178963e-01,  -4.08926167e-01,  -3.61095055e-01],
#        [  6.78768041e-01,  -8.25179659e-01,  -7.07808943e-01, ...,
#           8.12962251e-02,  -1.27885033e-03,  -8.94741562e-02]])

# %%
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))
score = rmsle_cv(ENet)
print("ElasticNet score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# ElasticNet score: 0.1248 (0.0144)

# %%
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)
score = rmsle_cv(KRR)
print("Kernel Ridge score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Kernel Ridge score: 0.1248 (0.0144)

# %%
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)
score = rmsle_cv(GBoost)
print("Gradient Boosting score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Gradient Boosting score: 0.1242 (0.0118)

# %%
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

score = rmsle_cv(model_xgb)
print("Xgboost score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Xgboost score: 0.1214 (0.0094)

# %%
import lightgbm as lgb
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

score = rmsle_cv(model_lgb)
print("LGBM score: {:.4f} ({:.4f})\n" .format(score.mean(), score.std()))
# Out:
# LGBM score: 0.1232 (0.0105)

# %%
class AveragingModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, models):
        self.models = models
        
    # we define clones of the original models to fit the data in
    def fit(self, X, y):
        self.models_ = [clone(x) for x in self.models]
        
        # Train cloned base models
        for model in self.models_:
            model.fit(X, y)

        return self
    
    #Now we do the predictions for cloned models and average them
    def predict(self, X):
        predictions = np.column_stack([
            model.predict(X) for model in self.models_
        ])
        return np.mean(predictions, axis=1)

# %%
averaged_models = AveragingModels(models = (ENet, GBoost, KRR, lasso))

score = rmsle_cv(averaged_models)
print(" Averaged base models score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
#  Averaged base models score: 0.1205 (0.0138)

# %%
class StackingAveragedModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, base_models, meta_model, n_folds=5):
        self.base_models = base_models
        self.meta_model = meta_model
        self.n_folds = n_folds
   
    # We again fit the data on clones of the original models
    def fit(self, X, y):
        self.base_models_ = [list() for x in self.base_models]
        self.meta_model_ = clone(self.meta_model)
        kfold = KFold(n_splits=self.n_folds, shuffle=True, random_state=156)
        
        # Train cloned base models then create out-of-fold predictions
        # that are needed to train the cloned meta-model
        out_of_fold_predictions = np.zeros((X.shape[0], len(self.base_models)))
        for i, model in enumerate(self.base_models):
            for train_index, holdout_index in kfold.split(X, y):
                instance = clone(model)
                self.base_models_[i].append(instance)
                instance.fit(X[train_index], y[train_index])
                y_pred = instance.predict(X[holdout_index])
                out_of_fold_predictions[holdout_index, i] = y_pred
                
        # Now train the cloned  meta-model using the out-of-fold predictions as new feature
        self.meta_model_.fit(out_of_fold_predictions, y)
        return self
   
    #Do the predictions of all base models on the test data and use the averaged predictions as 
    #meta-features for the final prediction which is done by the meta-model
    def predict(self, X):
        meta_features = np.column_stack([
            np.column_stack([model.predict(X) for model in base_models]).mean(axis=1)
            for base_models in self.base_models_ ])
        return self.meta_model_.predict(meta_features)

# %%
stacked_averaged_models = StackingAveragedModels(base_models = (ENet, GBoost, KRR),
                                                 meta_model = lasso)

score = rmsle_cv(stacked_averaged_models)
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# C:\Users\Youniz\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
# Stacking Averaged models score: 0.1189 (0.0138)

# %%
def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %%
stacked_averaged_models.fit(train.values, y_train)
stacked_train_pred = stacked_averaged_models.predict(train.values)
stacked_pred = np.expm1(stacked_averaged_models.predict(test.values))
print(rmsle(y_train, stacked_train_pred))
# Out:
# 0.0806900875963

# %%
model_xgb.fit(train, y_train)
xgb_train_pred = model_xgb.predict(train)
xgb_pred = np.expm1(model_xgb.predict(test))
print(rmsle(y_train, xgb_train_pred))
# Out:
# 0.0799014190135

# %%
model_lgb.fit(train, y_train)
lgb_train_pred = model_lgb.predict(train)
lgb_pred = np.expm1(model_lgb.predict(test.values))
print(rmsle(y_train, lgb_train_pred))
# Out:
# 0.0756438945208

# %%
print('RMSLE score on train data:')
print(rmsle(y_train,stacked_train_pred*0.70 +
               xgb_train_pred*0.15 + lgb_train_pred*0.15 ))
# Out:
# RMSLE score on train data:
# 0.0772398637165

# %%
ensemble = stacked_pred*0.70 + xgb_pred*0.15 + lgb_pred*0.15

# %%
ensemble
# Out:
# array([ 120033.49191444,  158971.5983623 ,  185426.45037499, ...,
#         168754.32550441,  118843.49202723,  218747.38776719])

# %%
final = pd.DataFrame()
test_id=house_test_sample["Id"]
final["Id"]=test_id

final["SalePrice"]=ensemble
final.to_csv('submission4.csv', index=False)
